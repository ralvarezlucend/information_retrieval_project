# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
df_cleaned = pd.read_csv("./cleaned_data.csv")

# %%
df_cleaned.columns
# Out:
# Index(['id', 'adult', 'belongs_to_collection', 'genres', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'release_date', 'runtime', 'spoken_languages', 'title', 'vote_average',
#        'vote_count', 'keywords'],
#       dtype='object')

# %% [markdown]
# #### just some helper functions

# %%
def convert_dict(column_name,key,value):
    # store just the ids and None/NaN otherwise
    d = dict()
    for i in df_cleaned[column_name]:
        j = eval(i)
        if j.get('id') != None:
            d.update({j.get(key) : j.get(value)})
    df_cleaned[column_name] = [eval(i).get(key) for i in df_cleaned[column_name]]
    return d

# %%
def convert_list_of_dict(column_name,key,value):
    # store just the list of ids in the df and dictionary stores all the mappings
    d_ = dict()
    l = []
    for i in df_cleaned[column_name]:
        l2 = []
        for j in eval(i):
            l2.append(j.get(key))
            d_.update({j.get(key): j.get(value)})
        l.append(l2)
    df_cleaned[column_name] = l
    return d_

# %%
df_cleaned['belongs_to_collection'].iloc[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %% [markdown]
# ### adult,popularity, release_date, runtime, title, vote_average, vote_count don't have to change anything

# %% [markdown]
# ### Convert belongs_to_collection to just the ids and store the dictionary with name somewhere else
# again gets the NaN values (setting to zero might be wrong!!)

# %%
dict_ids_to_collection = convert_dict('belongs_to_collection','id','name')

# %%
dict_ids_to_collection
# Out:
# {10194: 'Toy Story Collection',
#  119050: 'Grumpy Old Men Collection',
#  96871: 'Father of the Bride Collection',
#  645: 'James Bond Collection',
#  117693: 'Balto Collection',
#  3167: 'Ace Ventura Collection',
#  91698: 'Chili Palmer Collection',
#  9435: 'Babe Collection',
#  9818: 'Mortal Kombat Collection',
#  136214: 'Pocahontas Collection',
#  124935: 'The Lawnmower Man Collection',
#  43563: 'Friday Collection',
#  10924: 'From Dusk Till Dawn Collection',
#  122017: 'Screamers Collection',
#  256377: 'The Muppet Collection',
#  91430: 'The Neverending Story Collection',
#  14890: 'Bad Boys Collection',
#  120794: 'Batman Collection',
#  439053: 'Brooklyn Cigar Store Collection',
#  8819: 'Casper Collection',
#  9649: 'Mexico Trilogy',
#  1570: 'Die Hard Collection',
#  259398: 'Teenage Apocalypse Trilogy',
#  9328: 'Free Willy Collection',
#  286162: 'Power Rangers Collection',
#  328073: 'Síť (kolekce)',
#  9068: 'The Prophecy Collection',
#  247294: 'Showgirls Collection',
#  9887: 'Species Collection',
#  112399: 'Under Siege Collection',
#  23170: 'Burnt by the Sun Trilogy',
#  123800: 'Before... Collection',
#  182813: 'Clerks Collection',
#  96665: 'Dumb and Dumber Collection',
#  410261: 'A Goofy Movie Collection',
#  217704: 'The Vampire Chronicles',
#  10: 'Star Wars Collection',
#  286948: 'Nemesis Collection',
#  300546: 'Once were Warriors Collection',
#  48188: 'Poison Ivy Collection',
#  131: 'Three Colors Collection',
#  144200: 'Swan Princess Series',
#  53159: 'The Santa Clause Collection',
#  115142: 'Tales from the Crypt Collection',
#  115570: 'Star Trek: The Next Generation Collection',
#  192492: 'The Jack Ryan Collection',
#  9436: 'The Crow Collection',
#  351684: 'The Flintstones (Live-Action) Collection',
#  94032: 'The Lion King Collection',
#  8581: 'A Nightmare on Elm Street Collection',
#  43072: 'The Mask Collection',
#  37139: 'Naked Gun Collection',
#  167985: 'Richie Rich Collection',
#  43064: 'Speed Collection',
#  170452: 'Timecop Collection',
#  261203: 'Street Fighter',
#  439409: 'Fear Collection',
#  8050: 'Highlander Collection',
#  11716: 'Addams Family Collection',
#  162028: 'Stakeout Collection',
#  85861: 'Beverly Hills Cop Collection',
#  150156: 'City Slickers Collection',
#  252313: 'The Endless Summer Collection',
#  134011: 'The Fugitive / U.S. Marshals Collection',
#  412680: 'Hard Target Collection',
#  52988: 'Hot Shots! Collection',
#  159600: 'House Party Collection',
#  328: 'Jurassic Park Collection',
#  8580: 'The Karate Kid Collection',
#  5547: 'RoboCop Collection',
#  462565: 'The Secret Garden Collection',
#  105075: 'The Shadow Collection',
#  422837: 'Blade Runner Collection',
#  224478: 'The Brady Bunch Collection',
#  9888: 'Home Alone Collection',
#  86027: 'Aladdin Collection',
#  528: 'The Terminator Collection',
#  9743: 'The Hannibal Lecter Anthology',
#  153010: 'Beauty and the Beast Collection',
#  98580: 'Candyman Collection',
#  43058: 'Homeward Bound Collection',
#  141086: 'Heavy Metal Collection',
#  8917: 'Hellraiser Collection',
#  140910: 'All Dogs Go to Heaven Collection',
#  87359: 'Mission: Impossible Collection',
#  169452: 'DragonHeart Collection',
#  36694: 'Bloodsport Collection',
#  158391: 'The Apu Collection',
#  144146: 'Lemmy Caution Collection',
#  143766: 'The Substitute Collection',
#  52888: 'The Visitors Collection',
#  23026: 'Ghost in the Shell Collection',
#  529: 'Wallace & Gromit Collection',
#  116661: 'The Arrival Collection',
#  303969: 'Martin Scorsese’s World Cinema Project, Vol. 1',
#  424202: 'Trainspotting Collection',
#  304378: 'Independence Day Collection',
#  97456: 'The Hunchback of Notre Dame Collection',
#  86028: 'The Nutty Professor Collection',
#  115838: 'Escape From ... Collection',
#  230: 'The Godfather Collection',
#  269098: 'Police Story Collection',
#  19163: 'The Land Before Time Collection',
#  91361: 'Halloween Collection',
#  4438: 'The Space Odyssey Series',
#  47814: 'The Thin Man Collection',
#  261590: 'Living Dead Collection',
#  242765: 'In the Line of Duty Collection',
#  10709: 'The Mighty Ducks Collection',
#  87232: 'The Apple Dumpling Gang Collection',
#  181496: 'Davy Crockett Collection',
#  90348: 'Witch Mountain Collection',
#  12087: 'Herbie Collection',
#  216395: 'Parent Trap Collection',
#  294519: 'The Shaggy Dog Collection',
#  55419: 'Cinderella Collection',
#  271668: 'Caballeros Collection',
#  100970: 'The Fox and the Hound Collection',
#  355490: 'Freeway Collection',
#  86058: 'Dirty Dancing Collection',
#  118221: "Weekend at Bernie's Collection",
#  86336: 'Basic Instinct Collection',
#  115225: 'Children of the Corn Collection',
#  937: 'The Pink Panther (Original) Collection',
#  174218: 'The Howling Collection',
#  39460: 'The Water of the Hills Collection',
#  153948: 'Best of the Best Collection',
#  33071: 'Cheech & Chong Collection',
#  84: 'Indiana Jones Collection',
#  8091: 'Alien Collection',
#  48317: 'The Man With No Name Collection',
#  1960: 'Evil Dead Collection',
#  119674: 'Psycho Collection',
#  112636: 'The Blues Brothers Collection',
#  330605: 'The Sting Collection',
#  359005: 'The Jake Gittes Collection',
#  264: 'Back to the Future Collection',
#  55427: 'Fantasia Collection',
#  173344: 'Qatsi Collection',
#  397842: 'The Amityville Horror Collection',
#  422193: 'The Blob Collection',
#  218406: 'Frankenstein (Universal Series)',
#  257053: 'Carrie Collection',
#  10919: 'The Omen Collection',
#  498: 'Heart of Gold Collection',
#  307637: 'Jingle All the Way Collection',
#  105629: 'Paradise Lost Collection',
#  124916: '101 Dalmatians (Live-Action) Collection',
#  151: 'Star Trek: The Original Series Collection',
#  9329: 'Young Guns Collection',
#  86083: 'Grease Collection',
#  2366: 'The Jaws Collection',
#  2602: 'Scream Collection',
#  166379: 'Turbulence Collection',
#  393564: "McHale's Navy Collection",
#  108693: "National Lampoon's Vacation Collection",
#  86224: 'The Saint Collection',
#  207952: 'Barrytown Trilogy',
#  105995: 'Anaconda Collection',
#  1006: 'Austin Powers Collection',
#  174407: 'Warriors of Virtue Collection',
#  331475: 'Shiloh Collection',
#  182923: 'Tetsuo Collection',
#  86055: 'Men In Black Collection',
#  43055: 'Conan the Barbarian Collection',
#  126221: 'George of the Jungle Collection',
#  97445: 'Air Bud Collection',
#  10721: 'Mimic Collection',
#  142680: 'Alex Cross Collection',
#  135489: 'Wishmaster Collection',
#  3601: 'I Know What You Did Last Summer Collection',
#  103372: 'Mr. Bean Collection',
#  10522: 'Starship Troopers Collection',
#  372479: 'Les Boys',
#  351886: 'The Postman Collection',
#  71458: '3 Ninjas Collection',
#  33059: 'Wild Things Collection',
#  350402: 'Barney Collection',
#  221966: 'The Odd Couple Collection',
#  97771: 'Major League Collection',
#  378453: 'Henry Fool Collection',
#  87236: 'Mulan Collection',
#  19387: 'The X-Files Collection',
#  3169: 'Dr. Dolittle Collection',
#  945: 'Lethal Weapon Collection',
#  155474: 'French Connection Collection',
#  1575: 'Rocky Collection',
#  9735: 'Friday the 13th Collection',
#  123255: 'Prom Night Collection',
#  10455: "Child's Play Collection",
#  10453: 'Poltergeist Collection',
#  12263: 'The Exorcist Collection',
#  89151: 'The Gremlins Collection',
#  1657: 'Zorro Collection',
#  372257: 'The Poseidon Adventure Collection',
#  294468: 'Flubber Collection',
#  87250: 'Bambi Collection',
#  297143: 'Dexter Riley Collection',
#  72119: 'Honey, I Shrunk the Kids Collection',
#  97459: 'The Jungle Book Collection',
#  97460: 'Lady and the Tramp Collection',
#  33085: 'The Little Mermaid Collection',
#  100693: '101 Dalmatians (Animated) Collection',
#  55422: 'Peter Pan Collection',
#  57971: 'The Rescuers Collection',
#  248126: 'Splash Collection',
#  63043: 'TRON Collection',
#  141290: 'The Lord of the Rings Animated Collection',
#  263193: "Charlotte's Web Collection",
#  141292: 'The Secret Of NIMH Collection',
#  8783: 'Fievel Collection',
#  102782: 'House Collection',
#  87805: 'The Gods Must Be Crazy Collection',
#  143755: 'Henry: Portrait of a Serial Killer Collection',
#  264338: "Rosemary's Baby Collection",
#  47983: 'Killer Tomatoes! Collection',
#  735: 'Blade Collection',
#  432: 'Cube Collection',
#  90863: 'Rush Hour Collection',
#  52760: 'Urban Legend',
#  479888: 'The Thing Collection',
#  348843: 'Vampires Collection',
#  100286: 'Elizabeth Collection',
#  374384: 'Stepford Collection',
#  57129: 'Rugrats Collection',
#  374509: 'Godzilla (Showa) Collection',
#  374511: 'Godzilla (Heisei) Collection',
#  135495: 'King Kong (1933 series)',
#  135498: 'King Kong (1976 series)',
#  104833: 'Fletch Collection',
#  9338: 'Police Academy Collection',
#  5039: 'Rambo Collection',
#  89264: 'Romancing the Stone Collection',
#  86307: 'Cocoon Collection',
#  340623: 'The Gate Collection',
#  123213: 'The Fly (1958 series)',
#  109609: 'The Fly Collection',
#  111751: 'Texas Chainsaw Massacre Collection',
#  9332: 'Crocodile Dundee Collection',
#  387219: 'The Hustler Collection',
#  387618: '8MM Collection',
#  10789: 'Pet Sematary Collection',
#  33938: 'Airport Collection',
#  124934: 'Alligator Collection',
#  166698: 'Westworld Collection',
#  1709: 'Planet of the Apes Original Collection',
#  110127: 'Analyze Collection',
#  52789: 'Cruel Intentions Collection',
#  2344: 'The Matrix Collection',
#  1733: 'The Mummy Collection',
#  205860: 'The Black Mask Collection',
#  221544: 'The Mummy (Universal Series)',
#  138965: 'The Mummy (Hammer Series)',
#  8537: 'Superman Collection',
#  221539: 'Dracula (Universal Series)',
#  259027: 'The Wolf Man (Universal Series)',
#  123720: 'Frankenstein (Hammer Series)',
#  281644: 'Rocky Horror Collection',
#  87228: 'Swamp Thing Collection',
#  106768: 'Tarzan (Animation) Collection',
#  2806: 'American Pie Collection',
#  104068: 'Tales of the Four Seasons',
#  64750: 'Blair Witch Collection',
#  97768: 'Lake Placid Collection',
#  2980: 'Ghostbusters Collection',
#  237445: 'Inspector Gadget Collection',
#  185682: 'The Adventures of Antoine Doinel',
#  135502: 'Allan Quatermain Collection',
#  91663: 'Airplane Collection',
#  180854: 'Problem Child Collection',
#  201873: 'A Christmas Story Collection',
#  10713: 'Universal Soldier Collection',
#  123251: 'Iron Eagle Collection',
#  189295: 'The Spiders Serial',
#  143757: 'Stir of Echoes Collection',
#  98168: 'Fright Night Collection',
#  146136: 'Armour of God Collection',
#  47770: 'Phantasm Collection',
#  12203: 'Drunken Master Collection',
#  124492: 'The Dirty Dozen Collection',
#  59586: 'The Blue Lagoon collection',
#  380822: 'Penitenciaría - Colección',
#  122947: 'Omega Code Series',
#  381396: 'Bats Collection',
#  243598: 'The Best Man Collection',
#  89188: 'Harry Palmer Collection',
#  391047: 'On Any Sunday Collection',
#  248339: 'House on Haunted Hill Collection',
#  98036: 'Re-Animator Collection',
#  107725: 'Creepshow Collection',
#  212279: 'Piranha Collection',
#  398740: 'Mister Roberts Collection',
#  48037: 'Meatballs Collection',
#  34055: 'Pokémon Collection',
#  95051: 'The Up Series',
#  95664: 'Deuce Bigalow Collection',
#  135509: 'The Last Picture Show Collection',
#  321063: 'The Sinbad Collection',
#  99727: 'Stuart Little Collection',
#  421904: 'Batman (DC Universe Animated) Collection',
#  103573: 'Sister Act Collection',
#  8979: "Wayne's World Collection",
#  110179: 'The Cutting Edge Collection',
#  338282: 'Single White Female Collection',
#  87186: 'The Boondock Saints Collection',
#  327598: 'To Sir, with Love Collection',
#  2794: 'The Chronicles of Riddick Collection',
#  103577: 'The Whole Nine/Ten Yards Collection',
#  93568: 'Cross of Iron Collection',
#  124950: 'American Graffiti Collection',
#  8864: 'Final Destination Collection',
#  14377: 'Death Wish Collection',
#  1582: 'Teenage Mutant Ninja Turtles (Original) Collection',
#  8647: 'The Skulls Collection',
#  366826: 'Navarone Collection',
#  338327: 'Beach Party Collection',
#  170754: 'Arthur Collection',
#  466318: 'Bachelor Party Collection',
#  399: 'Predator Collection',
#  86105: 'American Psycho Collection',
#  159616: 'East is East Collection',
#  104847: 'Caddyshack Collection',
#  256484: 'Carnosaur Collection',
#  175858: 'Hidden Collection',
#  127280: 'The Three Mothers Collection',
#  342009: 'Die Nibelungen Filmreihe',
#  246839: 'Center Stage Collection',
#  179244: "Pee-wee's Collection",
#  96679: 'Road Trip Collection',
#  59567: 'Shanghai Noon Collection',
#  44979: "Big Momma's House Collection",
#  123726: 'Quatermass (Hammer series)',
#  107949: 'Puppet Master Collection',
#  424830: 'The Benji Collection',
#  157671: 'The Decline of Western Civilization Collection',
#  10456: 'Dirty Harry Collection',
#  109592: "Porky's Collection",
#  263866: "Nuke 'Em High Collection",
#  32135: 'The Toxic Avenger Collection',
#  174245: 'Alien Nation Collection',
#  8945: 'Mad Max Collection',
#  121195: '9½ Weeks Collection',
#  207447: 'Firestarter Collection',
#  495: 'Shaft Collection',
#  171439: 'F/X Collection',
#  46512: 'Missing in Action Collection',
#  173628: 'Nekromantik Collection',
#  4246: 'Scary Movie Collection',
#  748: 'X-Men Collection',
#  166376: 'Hollow Man Collection',
#  123256: 'Pumpkinhead Collection',
#  47391: 'Sleepaway Camp Collection',
#  123249: 'Ilsa, She Wolf of the SS Collection',
#  223564: 'The Cell Collection',
#  374512: 'Godzilla (Millennium) Collection',
#  25410: 'The Art of War Collection',
#  430186: 'Bring It On Collection',
#  8412: 'Anatomy Collection',
#  221537: 'Creature From The Black Lagoon (Universal Series)',
#  259401: 'The Invisible Man (Universal Series)',
#  138971: 'The Slumber Party Massacre Collection',
#  138974: 'The Sorority House Massacre Collection',
#  39244: 'Digimon Collection',
#  51509: 'Meet the Parents Collection',
#  240690: 'Billy Jack Collection',
#  44913: 'Ghoulies Collection',
#  86029: "Charlie's Angels Collection",
#  290973: 'Crouching Tiger, Hidden Dragon Collection',
#  106498: 'Dungeons & Dragons Collection',
#  52783: 'Wall Street Collection',
#  178117: "The Emperor's New Groove Collection",
#  93220: 'Miss Congeniality Collection',
#  115822: 'Dracula 2000 Collection',
#  312735: 'Annie Collection',
#  107469: 'Save The Last Dance Collection',
#  141282: 'The Brave Little Toaster Collection',
#  330555: 'Ernest Collection',
#  109076: 'Lost Boys Collection',
#  124951: 'Mannequin Collection',
#  109082: 'Left Behind Collection',
#  287016: "Wong Kar-Wai's Informal Collection",
#  421084: 'Disneys Große Pause',
#  366444: 'Demetrius Filmreihe',
#  116847: 'Dr. Phibes Collection',
#  48190: 'Revenge of the Nerds Collection',
#  257571: 'C.H.U.D. Collection',
#  86486: 'Spy Kids Collection',
#  8936: 'Bridget Jones Collection',
#  353325: 'Joe Dirt Collection',
#  2150: 'Shrek Collection',
#  441439: 'Alienation Trilogy',
#  110021: 'The Magnificent Seven Collection',
#  100965: 'Atlantis Collection',
#  2467: 'Tomb Raider Collection',
#  9485: 'The Fast and the Furious Collection',
#  3963: 'The Crimson Rivers Collection',
#  87014: 'Cats & Dogs Collection',
#  421566: 'Totò Collection',
#  101688: 'Cannonball Run Collection',
#  427956: 'Dr Goldfoot Collection',
#  140760: 'Final Fantasy Collection',
#  86024: 'Legally Blonde Collection',
#  10893: 'Critters Collection',
#  182617: 'Elvira Collection',
#  101471: 'Return of the Living Dead Collection',
#  89272: 'The Man From Snowy River Collection',
#  86347: 'Short Circuit Collection',
#  126220: 'The Waxwork Collection',
#  91945: 'American Ninja Collection',
#  91746: "Bill & Ted's Most Excellent Collection",
#  98853: 'Cyborg Collection',
#  351230: 'Dream a Little Dream Collection',
#  186102: 'Eddie and the Cruisers Collection',
#  88735: 'K-9 Collection',
#  105322: 'Kickboxer Collection',
#  9521: "Look Who's Talking Collection",
#  87631: 'The Musketeers Collection',
#  224976: 'Road House Collection',
#  138706: 'The Stepfather Collection',
#  87536: 'Warlock Collection',
#  104716: 'Basket Case Collection',
#  107674: 'The Princess Diaries Collection',
#  239968: 'La cage aux folles',
#  168182: 'Philo & Clyde Collection',
#  94899: 'Jeepers Creepers Collection',
#  383632: 'A Man Called Horse Collection',
#  352789: 'Zoolander Collection',
#  166378: 'Joy Ride Collection',
#  41649: 'The Party Collection',
#  178106: 'Darko Collection',
#  137696: 'Monsters, Inc. Collection',
#  276838: 'When a Stranger Calls Collection',
#  1241: 'Harry Potter Collection',
#  449750: 'Fanny Brice Collection',
#  106000: 'Beastmaster Collection',
#  284024: 'The Exterminator Collection',
#  211753: 'Caprona Collection',
#  98513: 'Behind Enemy Lines Collection',
#  304: "Ocean's Collection",
#  119: 'The Lord of the Rings Collection',
#  476056: 'Fritz the Cat Collection',
#  395591: 'Sex and Zen Collection',
#  93295: '48 Hrs. Collection',
#  87214: 'The Sandlot Collection',
#  449462: 'Super Troopers Collection',
#  262011: 'Sleuth Collection',
#  124879: 'State Property Collection',
#  215326: 'The Bad New Bears Collection',
#  460292: 'The Lone Ranger (Clayton Moore) Collection',
#  122952: 'Vampire Hunter D Collection',
#  19160: 'FernGully Collection',
#  133923: 'Zombi Collection',
#  108669: 'Get Smart Collection',
#  221308: 'Oh, God! Collection',
#  8354: 'Ice Age Collection',
#  17255: 'Resident Evil Collection',
#  456980: 'The Paleface Collection',
#  135441: 'Road to Collection',
#  87220: 'Smokey and the Bandit Collection',
#  112537: 'Sällskapsresorna',
#  43220: 'National Lampoon’s Van Wilder Collection',
#  261526: 'Slap Shot Collection',
#  389767: 'My Big Fat Greek Wedding Collection',
#  256729: 'War Trilogy',
#  406817: 'Horror High Collection',
#  107688: '3 Men Collection',
#  116669: 'The Scorpion King Collection',
#  5202: 'Wild Orchid Collection',
#  556: 'Spider-Man Collection',
#  178654: 'White Fang Collection',
#  31562: 'The Bourne Collection',
#  86860: 'Scooby-Doo Collection',
#  97461: 'Lilo & Stitch Collection',
#  363014: 'Like Mike Collection',
#  167456: 'Our Man Flint Collection',
#  113635: 'The Modesty Blaise Collection',
#  52785: 'xXx Collection',
#  356437: 'Living Trilogy',
#  115839: 'Blue Crush Collection',
#  117777: 'Undisputed Collection',
#  363966: 'Care Bears Collection',
#  135501: '976-EVIL Collection',
#  176097: 'Barbershop Collection',
#  9518: 'The Transporter Collection',
#  267922: 'The Hills Have Eyes (Original) Collection',
#  277739: 'Heaven, Hell and Purgatory Collection',
#  123724: 'Dracula (Hammer Series)',
#  386818: 'Django - Original films',
#  14563: 'The Ring Collection',
#  288280: 'Saturday Night Fever Collection',
#  457305: 'Man of Marble/Iron Collection',
#  373538: 'Enter the Ninja Collection',
#  97237: 'Faces of Death Collection',
#  169329: 'Göta kanal collection',
#  295862: 'The BRD Collection',
#  264437: 'My Bloody Valentine Collection',
#  17178: 'Jackass Collection',
#  43063: 'Half Past Dead Collection',
#  148517: "Pagnol, Childhood's Memories",
#  88574: 'Scanners Collection',
#  218293: 'Brother Collection',
#  12075: 'Elling Collection',
#  296429: 'I Spit on Your Grave (Original) Collection',
#  374386: 'Anglo-Zulu War Collection',
#  140126: 'Vabank (Collection)',
#  63170: 'Jönsson Gang',
#  164397: 'Class of 1999 Collection',
#  423877: 'Turkish Star Wars',
#  85960: 'My Girl Collection',
#  104842: 'Blue Collar Comedy Tour Collection',
#  227147: 'Tokyo Decadence series',
#  10517: 'Le Gendarme de St. Tropez Collection',
#  315750: 'They Call Me Bruce Collection',
#  137766: 'Zapped Collection',
#  195441: 'Dennis the Menace Collection',
#  405393: 'The Black Stallion Collection',
#  375886: 'Willard',
#  354210: 'Born Free Trilogy',
#  93369: 'Ringu Collection',
#  261057: 'I Am Curious Collection',
#  100992: 'The Flicka Collection',
#  8385: "Aki Kaurismäki's Finland trilogy",
#  105625: 'House of 1000 Corpses Collection',
#  228887: 'Daddy Day Camp Collection',
#  92222: "Breakin' Collection",
#  239766: 'The Klapisch Trilogy',
#  124949: 'Almighty Collection',
#  137697: 'Finding Nemo Collection',
#  52985: 'Wrong Turn Collection',
#  431417: 'Nevada Smith Collection',
#  1565: '28 Days/Weeks Later Collection',
#  295: 'Pirates of the Caribbean Collection',
#  86117: 'Johnny English Collection',
#  194752: 'Trilogie',
#  289531: 'Gator Collection',
#  221111: 'S.W.A.T. Collection',
#  91427: 'Agent Cody Banks Collection',
#  91799: 'Tremors Collection',
#  7505: 'Elements Trilogy',
#  330892: 'Sides of the Bed',
#  201576: 'The Cabin Fever Collection',
#  10457: 'Once Upon a Time in China Collection',
#  2326: 'Underworld Collection',
#  409138: 'Yossi Collection',
#  201778: 'Dorm Daze Collection',
#  187736: 'Leningrad Cowboys Collection',
#  168880: 'Beethoven Collection',
#  11794: 'Ginger Snaps Collection',
#  117927: 'House of the Dead Collection',
#  2883: 'Kill Bill Collection',
#  425175: 'Texas Chainsaw (Reboot) Collection',
#  96472: 'Brother Bear Collection',
#  264335: 'The Eye Collection',
#  478628: 'Sherlock Holmes (1939 series)',
#  423173: 'Bad Santa Collection',
#  45154: 'Darkman Collection',
#  208765: 'Europa Trilogy',
#  151263: 'WarGames Collection',
#  397444: 'Kindergarten Cop Collection',
#  16302: 'Battle Royale Collection',
#  43066: 'Teen Wolf Collection',
#  19285: 'Leprechaun Collection (Original Series)',
#  144689: 'Honey Collection',
#  114783: 'Cheaper by the Dozen Collection',
#  245129: 'Pumping Iron Collection',
#  157890: 'The Matt Helm Collection',
#  52749: 'The Butterfly Effect Collection',
#  353721: 'You Got Served Collection',
#  158373: 'The Lost Skeleton Collection',
#  201930: 'Blacula Collection',
#  1952: 'USA: Land of Opportunities Collection',
#  17235: 'Hellboy Collection',
#  86334: 'The Prince & Me Collection',
#  299748: 'Walking Tall Collection',
#  99606: 'Mean Girls Collection',
#  109608: 'Van Helsing Collection',
#  205977: 'The Kingdom',
#  404111: '100 Girls Collection',
#  10441: 'Babylon 5 Collection',
#  126166: 'The Delta Force Collection',
#  272673: 'Cat People Collection',
#  159340: 'Bang Rajan Collection',
#  14246: 'Sniper Collection',
#  478442: 'Lammbock Collection',
#  122945: 'The Legend Collection',
#  123740: 'Vampire Karnstein (Hammer series)',
#  308153: 'The Cheerleaders - Collection',
#  48829: 'The Streetfighter Collection',
#  145494: 'The Gidget Collection',
#  286935: 'Silence of God Trilogy by Ingmar Bergman',
#  185667: 'The Complete Monterey Pop Festival',
#  58588: 'Infernal Affairs Collection',
#  349889: 'Robot Jox Collection',
#  434533: 'Death Race Original Collection',
#  434270: 'Lew Harper Collection',
#  95891: 'In China They Eat Dogs Collection',
#  289288: 'Per Fly trilogien (Samling)',
#  192532: 'Dead or Alive Collection',
#  11140: 'Dr. Mabuse Collection',
#  145901: 'Lupin the Third Collection',
#  448468: 'Grey Gardens Collection',
#  86115: 'Garfield Collection',
#  475802: 'Super Size Me Collection',
#  85473: 'The Human Condition',
#  476054: 'The Hitcher (1986) Collection',
#  145784: 'The Philadelphia Experiment - Collezione',
#  211721: 'Taxi Collection',
#  280539: 'Lassie (Kinofilme)',
#  93791: 'Anchorman Collection',
#  437451: 'Cinderella Story Collection',
#  138163: 'Trylogia Sienkiewicza',
#  306882: 'Thunderbirds (Animation) Collection',
#  171586: 'PTU Collection',
#  30663: 'Harold & Kumar Collection',
#  115762: 'AVP Collection',
#  146534: 'Without a Paddle Collection',
#  374418: 'The Mangler Collection',
#  136218: 'Night of the Demons Collection',
#  168186: 'Witchboard Collection',
#  256297: "It's Alive Collection",
#  1974: 'The Grudge Collection',
#  656: 'Saw Collection',
#  468222: 'The Incredibles Collection',
#  52984: 'National Treasure Collection',
#  275402: 'SpongeBob Collection',
#  208602: "That's Entertainment Collection",
#  48802: 'I Love a Mystery movie series',
#  438087: 'Topper Collection',
#  158365: 'Why We Fight',
#  426985: 'Ivan The Terrible Collection',
#  84923: 'The Orphic Trilogy',
#  135508: 'Allan Quatermain (1950 series)',
#  12077: "St. Trinian's Collection",
#  102452: 'Samurai Collection',
#  94039: 'Asterix and Obelix (Animation) Collection',
#  161766: 'Gamera Films',
#  212525: 'Trinità  Collection',
#  308465: 'The Emigrants Collection',
#  105764: 'The Tall Blond Man Collection',
#  102128: 'Lone Wolf and Cub Collection',
#  409026: 'Nobody Collection',
#  157504: 'Walking Tall Original Collection',
#  39438: 'Emmanuelle Collection',
#  391040: 'Gone in 60 Seconds Trilogy',
#  211860: 'Mountain Family Robinson Collection',
#  405256: 'Dolemite Collection',
#  107473: 'Ирония судьбы (Коллекция)',
#  334563: 'The Sister Street Fighter Collection',
#  294834: 'Vixens Collection',
#  188458: 'Trilogy of Terror Collection',
#  255702: 'The Rutles Collection',
#  52835: 'French Fried Vacation',
#  14095: 'Barefoot Gen Collection',
#  133830: 'Star Wars: The Ewok Adventures Collection',
#  256296: 'Silent Night, Deadly Night Collection',
#  94035: 'Anne of Green Gables Collection',
#  284111: 'Barbarian Queen Collection',
#  430201: 'Demons Collection',
#  155421: 'Mr. Vampire Collection',
#  74083: 'Flodder Collection',
#  99635: 'A Better Tomorrow Collection',
#  160468: 'The Frogtown Collection',
#  324149: 'Koker Trilogy',
#  9046: 'A Chinese Ghost Story Collection',
#  98435: 'Patlabor Collection',
#  476066: 'Begotten Collection',
#  361140: 'House of Angels Collection',
#  151861: 'Lonesome Dove Collection',
#  192167: 'The Bride with White Hair Collection',
#  86341: 'Fortress Collection',
#  278467: 'Trilogía de la violencia de Michael Haneke',
#  309259: 'Naked Collection',
#  473943: 'Gonin collection',
#  190435: 'Street Fighter Collection',
#  203178: 'Jack Frost Collection',
#  137913: 'The Hunters Collection',
#  203910: 'Pusher Collection',
#  362047: 'Bikini Summer Collection',
#  142717: 'The Cremaster Cycle',
#  108043: 'Hamilton Collection',
#  2248: 'Torrente Collection',
#  344936: 'Unna Trilogie',
#  149191: 'Lady Snowblood Collection',
#  404770: 'Superman (DC Universe Animated) Collection',
#  96850: 'Evangelion Collection',
#  338416: 'Kirikou',
#  107462: 'Osobennosti Natsionalnoy ... - Collection',
#  268014: 'The Big Bottom Box',
#  164394: 'If These Walls Could Talk Collection',
#  206072: 'Running Out Of Time Collection',
#  426370: 'The Wog Boy Collection',
#  103190: 'The Female Prisoner Series',
#  379475: 'Batman Beyond Collection',
#  2396: 'Asterix and Obelix Collection',
#  473850: 'My Sassy Girl Collection',
#  118657: 'Annika Bengtzon Collection',
#  101676: 'My Wife is a Gangster Collection',
#  386495: 'Fubar Collection',
#  4563: 'The Vengeance Collection',
#  308645: 'The Foreigner Collection',
#  24726: 'Johan Falk Collection',
#  279836: 'Herr Lehmann Filmreihe',
#  1972: 'Ju-on Collection',
#  377545: 'Samurai Trilogy',
#  192541: 'The Twins Effect Collection',
#  371950: 'Dark Woods Collection',
#  126580: 'One Missed Call Collection',
#  53154: 'Inuyasha Collection',
#  94589: 'Ong Bak Collection',
#  306063: 'Saints and Soldiers Collection',
#  86113: 'Open Water Collection',
#  475520: 'The Yes Men Collection',
#  107461: 'Bummer Collection',
#  101246: 'Azumi Collection',
#  476065: 'What the Bleep! Collection',
#  102777: 'White Noise Collection',
#  191023: 'The Yakuza Papers Collection',
#  251858: 'Brancaleone Collection',
#  87800: 'Appleseed Collection',
#  11875: 'Pippi Longstocking',
#  413937: 'Father Flanagan Collection',
#  275873: 'Dr. Who Collection',
#  176118: 'The Are We Collection',
#  149704: 'Alone in the Dark Collection',
#  96937: 'The Boogeyman Collection',
#  437628: 'Constantine Collection',
#  3106: 'World of Watches Collection',
#  384920: 'No Retreat, No Surrender Collection',
#  169851: 'The ChubbChubbs Collection',
#  108170: 'The Blind Dead Collection',
#  101646: 'Vares Collection',
#  385721: 'Zu Warriors Collection',
#  135179: 'Sin City Collection',
#  167691: 'Trilogy of Life',
#  97919: 'The Love Comes Softly Collection',
#  96887: 'Zatôichi: The Blind Swordsman',
#  441443: 'Ukraine Trilogy',
#  14740: 'Madagascar Collection',
#  17368: 'The Sisterhood of the Traveling Pants Collection',
#  263: 'The Dark Knight Collection',
#  150954: 'My Friends Collection',
#  9744: 'Fantastic Four Collection',
#  131780: 'Whispering Corridors Collection',
#  332357: 'The Dukes Of Hazzard Collection',
#  220448: 'Mr. Wong Collection',
#  93731: 'Waiting Collection',
#  152544: 'Green Street Hooligans Collection',
#  174386: 'Into the Blue Collection',
#  110177: 'Goal! Collection',
#  206921: 'Star Wreck Collection',
#  298820: 'American Pie (Spin-off) Collection',
#  65249: 'Tarzan (Johnny Weissmuller series)',
#  285564: 'Jarhead Collection',
#  268098: 'Wolf Creek Collection',
#  87258: 'The Descent Collection',
#  321061: 'The Wild Geese Collection',
#  420: 'The Chronicles of Narnia Collection',
#  378268: 'Havoc Collection',
#  117952: 'The Dentist Collection',
#  107471: 'Yamakasi - Collection',
#  85946: 'District 13 Collection',
#  97307: 'BloodRayne Collection',
#  86578: 'Hostel Collection',
#  87255: 'Hoodwinked! Collection',
#  189159: 'Project A Collection',
#  148324: 'Uuno Turhapuro',
#  35792: 'Nanny McPhee Collection',
#  157626: 'The Comedians Of Comedy Collection',
#  130440: 'The Pink Panther (Steve Martin) Collection',
#  123218: 'Troll Collection',
#  55428: 'Curious George Collection',
#  124188: 'Pulse Collection',
#  159613: 'Election Collection',
#  286904: 'Ultimate Avengers Collection',
#  8918: 'The Hills Have Eyes (Reboot) Collection',
#  64748: 'Silent Hill Collection',
#  251970: 'The Protector Collection',
#  158038: 'Die Nibelungen Collection',
#  115776: 'Robert Langdon Collection',
#  87118: 'Cars Collection',
#  296872: 'See No Evil Collection',
#  87253: 'High School Musical Collection',
#  351721: 'The Sheriff and the Satellite Kid Collection',
#  246091: 'Krrish Collection',
#  85943: 'Night at the Museum Collection',
#  64751: 'Crank Collection',
#  86092: 'Step Up Collection',
#  417491: 'Bon Cop Bad Cop Collection',
#  156240: 'The Heroic Trio Collection',
#  44917: 'Swordsman Collection',
#  66761: 'Open Season Collection',
#  166373: 'The Marine Collection',
#  98430: 'Feast Collection',
#  261382: "Clint Eastwood's Iwo Jima Collection",
#  266846: 'Corto Maltese',
#  92012: 'Happy Feet Collection',
#  91588: 'OSS 117 Collection',
#  297371: 'Reeker Collection',
#  123717: 'She Collection',
#  102008: 'Another Gay Movie Collection',
#  123438: 'Loose Change Collection',
#  141084: "Happily N'Ever After Collection",
#  160727: 'Stomp the Yard Collection',
#  85817: 'Arthur and the Invisibles Collection',
#  11582: 'Don Camillo Collection',
#  96680: "Smokin' Aces Collection",
#  164395: 'The Messengers Collection',
#  376970: 'Cocaine Cowboys',
#  436982: 'SPL Collection',
#  101385: 'Trailer Park Boys Collection',
#  90306: 'Ghost Rider Collection',
#  159603: 'Kidulthood Collection',
#  108125: 'The 36th Chamber of Shaolin Collection',
#  187089: 'Emil i Lönneberga',
#  285130: '2001 Maniacs Collection',
#  269190: 'The Ultimate Collection',
#  125570: '300 Collection',
#  86112: 'Vacancy Collection',
#  375228: 'The Condemned Collection',
#  254636: 'Maniac Cop Collection',
#  376863: 'This is England Collection',
#  85890: 'The Librarian Collection',
#  325798: 'Star Crash Collection',
#  436295: "Surf's Up Collection",
#  339577: 'Grindhouse Collection',
#  8650: 'Transformers Collection',
#  86797: 'Arn collection',
#  369380: 'If I Were You Collection',
#  2704: 'The Bible Collection',
#  442352: 'Brice Collection',
#  126209: 'Halloween (Rob Zombie Series) Collection',
#  138908: '2 Days In... Collection',
#  353754: 'Trilogía Sollima',
#  45355: 'Kevin Smith: Silent Bob Speaks!',
#  91660: '30 Days of Night Collection',
#  143588: 'Why Did I Get Married Collection',
#  119581: 'Elite Squad Collection',
#  140758: 'Decoys Collection',
#  464270: 'The Man from Earth Collection',
#  390096: 'Hitman Collection',
#  167613: 'Alvin and the Chipmunks Collection',
#  13800: 'Futurama Collection',
#  113679: 'Design Trilogy',
#  472781: 'Inoshika Ocho series',
#  264339: 'The Hamiltons Collection',
#  215456: 'Keinohrhasen Filmreihe',
#  91697: 'Battlestar Galactica (Reboot) Collection',
#  74508: '[REC] Collection',
#  122922: 'In the Name of the King Collection',
#  124901: 'Hatchet Collection',
#  286177: 'Footsoldier Collection',
#  96682: 'Zeitgeist Collection',
#  238419: 'Anders Matthesen',
#  96676: 'Never Back Down Collection',
#  385720: 'Zebraman Collection',
#  232844: "Nim's Island Collection",
#  124881: 'Street Kings Collection',
#  108804: 'Outpost Collection',
#  131292: 'Iron Man Collection',
#  135483: 'Taken Collection',
#  44215: 'Stargate SG-1 Collection',
#  50457: 'Sex and the City Collection',
#  77816: 'Kung Fu Panda Collection',
#  314917: 'Flesh Gordon Collection',
#  462400: 'Wanted - Collection',
#  369005: 'Ten Minutes Older... (Collection)',
#  25542: 'An American Girl Collection',
#  363015: 'Frosty the Snowman Collection',
#  458558: 'Mamma Mia! Collection',
#  76291: 'Simon Brenner Collection',
#  72547: 'Journey Collection',
#  102019: 'Death Note Collection',
#  118828: 'Space Chimps Collection',
#  108502: 'The Discworld Collection',
#  96677: 'Red Cliff Collection',
#  86116: 'Death Race Collection',
#  105324: 'Mirrors Collection',
#  3292: 'Tulse Luper',
#  266731: 'Cat Stevens y Hutch Bessy Trilogy',
#  321065: 'The Sabata Collection',
#  141615: 'Niko - Coleccion',
#  123932: 'Quarantine Collection',
#  476063: 'Guinea Pig Collection',
#  192174: 'Crows Collection',
#  148055: 'Camp Rock Collection',
#  87256: 'Beverly Hills Chihuahua Collection',
#  158376: 'Hanzo the Razor Collection',
#  124930: 'King of the Zombies Collection',
#  33514: 'The Twilight Collection',
#  280562: 'The Guyver Collection',
#  86774: 'Che Collection',
#  201061: 'War of the Worlds Collection',
#  230532: 'Marley & Me Collection',
#  59235: 'Jesse Stone Collection',
#  70068: 'Ip Man Collection',
#  251383: 'The Gamers Collection',
#  85945: 'The Mesrine Collection',
#  195646: 'Galaxy Express 999 Collection',
#  328372: 'Mall Cop Collection',
#  96661: 'Afro Samurai Collection',
#  47627: 'Trancers Collection',
#  156152: 'La Trilogie Marseillaise',
#  169740: 'The Haunting in Connecticut Collection',
#  477050: "Takashi Miike's Young Thugs series",
#  24761: 'The Millennium Collection',
#  110041: 'Naked Fear Collection',
#  286006: 'Rest Stop Collection',
#  183256: 'Kiler Collection',
#  457550: 'Sugata Sanshirō Collection',
#  265782: 'The Desert Collection',
#  453993: 'The Wolverine Collection',
#  115575: 'Star Trek: Alternate Reality Collection',
#  413661: 'Charlie Chan (Sidney Toler) Collection',
#  10964: 'Flatfoot Collection',
#  240156: 'Sami Swoi Collection',
#  140612: 'Fullmetal Alchemist Collection',
#  86119: 'The Hangover Collection',
#  165743: 'Ranma Collection',
#  261240: 'U Pana Boga Collection',
#  286038: 'Dead Snow Collection',
#  373918: 'Garfield (Animation) Collection',
#  75014: 'How I Unleashed World War II',
#  26863: 'Caprinos Eventyrlige Verden',
#  350836: 'Dark Planet Collection',
#  165369: 'The Collector Collection',
#  135468: 'G.I. Joe (Live-Action) Collection',
#  221622: '12 Rounds Collection',
#  353708: 'Kill Buljo Collection',
#  210303: 'Rebuild of Evangelion',
#  190135: 'Love Hina Collection',
#  404148: 'Olympia',
#  109044: 'Shadow Warriors',
#  37261: 'The Carry On Collection',
#  141448: 'Fuga de cerebros - Collection',
#  158643: 'Laid to Rest Collection',
#  177467: 'Cloudy with a Chance of Meatballs Collection',
#  41437: 'Paranormal Activity Collection',
#  378025: 'Die Fritz Lang Indien-Edition',
#  368982: 'MVP',
#  282246: "Mickey's Upon a Christmas Collection",
#  175722: 'The Gorky Collection',
#  87096: 'Avatar Collection',
#  102322: 'Sherlock Holmes Collection',
#  209739: 'MacGyver (TV Movies) Collection',
#  244242: 'Ninja Collection',
#  264481: 'Mega Shark Collection',
#  242587: 'Rudolph the Red-Nosed Reindeer Collection',
#  38451: 'Charlie Chan (Warner Oland) Collection',
#  454520: 'Captain Harlock Collection',
#  475511: 'Steal This Film Collection',
#  179919: 'Percy Jackson Collection',
#  222634: 'Tooth Fairy Collection',
#  261307: 'Alice in Wonderland Collection',
#  86668: 'Elektra Luxx Collection',
#  379920: 'Deadly Prey Collection',
#  380006: 'Mondo Cane Collection',
#  46082: 'Ma and Pa Kettle Collection',
#  313576: 'Hot Tub Time Machine Collection',
#  89137: 'How to Train Your Dragon Collection',
#  458017: 'Tom and Jerry Collection',
#  86780: 'Clash of the Titans Collection',
#  179892: 'Kick-Ass Collection',
#  97156: 'Varg Veum Collection',
#  86110: 'Diary of a Wimpy Kid Collection',
#  314042: 'Onomichi Trilogy',
#  168618: 'The Moment After Collection',
#  142182: 'Bananas!* Collection',
#  211075: 'Panda! Go Panda! Collección',
#  96671: 'The Human Centipede Collection',
#  119234: 'Stray Cat Rock Collection',
#  12141: '3 Men (Original) Collection',
#  435347: '男はつらいよ シリーズ',
#  264434: 'Demonic Toys Collection',
#  429234: 'Trilogia Zé do Caixão',
#  463068: 'Täällä Pohjantähden alla (Timo Koivusalo)',
#  283417: 'Rampage Collection',
#  33878: 'Destricted',
#  86066: 'Despicable Me Collection',
#  180546: 'Grown Ups Collection',
#  303872: 'Little Nicholas Collection',
#  126125: 'The Expendables Collection',
#  104830: 'Piranha 3D Collection',
#  294172: 'Tekken Collection',
#  257899: "The President's Man Collection",
#  425164: 'Dragon Ball Z (Movie) Collection',
#  177675: 'The Last Exorcism Collection',
#  225543: 'Gasland Collection',
#  210006: 'Machete Collection',
#  360342: 'Tarzan (Lex Barker series)',
#  278920: 'Vampires Suck Collection',
#  220872: 'Men in the City Collection',
#  290933: 'Superman / Batman (Animated) Collection',
#  89959: 'Mr. Moto Collection',
#  306926: 'Monsters Collection',
#  295777: 'Korengal Valley Documentaries',
#  163902: 'RED Collection',
#  11118: 'The Olsen Gang Collection',
#  166844: "Sammy's Adventure Collection",
#  324371: 'The Riffs Trilogy',
#  167716: 'The Bill Douglas Trilogy',
#  ...}

# %%
with open("./new_movie_data/dict/ids_to_collection.pkl","wb") as f:
    pickle.dump(dict_ids_to_collection,f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 with open("./new_movie_data/dict/ids_to_collection.pkl","wb") as f:
#       2     pickle.dump(dict_ids_to_collection,f)
#
# File ~/anaconda3/envs/ir/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './new_movie_data/dict/ids_to_collection.pkl'

# %%
with open("./new_movie_data/dict/ids_to_collection.pkl","rb") as f:
    d = pickle.load(f)
d[df_cleaned.belongs_to_collection.iloc[0]]
# Out:
# 'Toy Story Collection'

# %% [markdown]
# ### Convert genres to just a list of ids and store the dictionary with name somewhere else

# %%
dict_ids_to_genres = convert_list_of_dict('genres','id','name')

# %%
with open("./new_movie_data/dict/ids_to_genres.pkl","wb") as f:
    pickle.dump(dict_ids_to_genres,f)

# %%
with open("./new_movie_data/dict/ids_to_genres.pkl","rb") as f:
    d = pickle.load(f)
[d.get(i) for i in df_cleaned.genres.iloc[0]]
# Out:
# ['Animation', 'Comedy', 'Family']

# %% [markdown]
# ### removing the column original title and original language not that useful - since title and spoken languages already exist

# %%
remove_col = ['original_language','original_title']

# %% [markdown]
# ### HAVE TO DECIDE WHAT TO DO WITH THE OVERVIEW

# %% [markdown]
# ### production companies - empty list if no information

# %%
df_cleaned.production_companies.iloc[1]
# Out:
# "[{'name': 'TriStar Pictures', 'id': 559}, {'name': 'Teitler Film', 'id': 2550}, {'name': 'Interscope Communications', 'id': 10201}]"

# %%
dict_ids_to_prod = convert_list_of_dict('production_companies','id','name')

# %%
with open("./new_movie_data/dict/ids_to_prod.pkl","wb") as f:
    pickle.dump(dict_ids_to_prod,f)

# %%
with open("./new_movie_data/dict/ids_to_prod.pkl","rb") as f:
    d = pickle.load(f)
[d.get(i) for i in df_cleaned.production_companies.iloc[1]]
# Out:
# ['TriStar Pictures', 'Teitler Film', 'Interscope Communications']

# %% [markdown]
# ### Spoken Languages

# %%
df_cleaned.spoken_languages.iloc[341]
# Out:
# "[{'iso_639_1': 'fr', 'name': 'Français'}, {'iso_639_1': 'en', 'name': 'English'}]"

# %%
dict_iso_to_language = convert_list_of_dict("spoken_languages",'iso_639_1','name')

# %%
with open("./new_movie_data/dict/iso_to_lang.pkl","wb") as f:
    pickle.dump(dict_iso_to_language,f)

# %%
dict_id_to_iso = dict()
dict_iso_to_id = dict()
for j,i in enumerate(dict_iso_to_language.keys()):
    dict_id_to_iso.update({j+1:i})
    dict_iso_to_id.update({i:j+1})

# %%
with open("./new_movie_data/dict/id_to_iso.pkl","wb") as f:
    pickle.dump(dict_id_to_iso,f)

# %%
l = []
for i in df_cleaned.spoken_languages:
    l2 = []
    for j in i:
        l2.append(dict_iso_to_id.get(j))
    l.append(l2)
df_cleaned.spoken_languages = l

# %%
with open("./new_movie_data/dict/iso_to_lang.pkl","rb") as f:
    d = pickle.load(f)
with open("./new_movie_data/dict/id_to_iso.pkl","rb") as f:
    d_ = pickle.load(f)
[d.get(d_.get(i)) for i in df_cleaned.spoken_languages.iloc[341]]
# Out:
# ['Français', 'English']

# %% [markdown]
# ### Keywords

# %%
df_cleaned.keywords.iloc[0]
# Out:
# "[{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]"

# %%
dict_ids_to_keywords = convert_list_of_dict('keywords','id','name')

# %%
with open("./new_movie_data/dict/ids_to_keywords.pkl","wb") as f:
    pickle.dump(dict_ids_to_keywords,f)

# %%
with open("./new_movie_data/dict/ids_to_keywords.pkl","rb") as f:
    d = pickle.load(f)
[d.get(i) for i in df_cleaned.keywords.iloc[0]]
# Out:
# ['jealousy',
#  'toy',
#  'boy',
#  'friendship',
#  'friends',
#  'rivalry',
#  'boy next door',
#  'new toy',
#  'toy comes to life']

# %%
df_cleaned = df_cleaned[[i for i in list(df_cleaned.columns) if i not in remove_col ]]

# %%
df_cleaned = df_cleaned.copy()
df_cleaned.loc[:, 'adult'] = df_cleaned['adult'].astype(int)

# %%
df_cleaned.head()
# Out:
#       id  adult  belongs_to_collection           genres  \
# 0    862      0                10194.0  [16, 35, 10751]
# 1   8844      0                    NaN  [12, 14, 10751]
# 2  15602      0               119050.0      [10749, 35]
# 3  31357      0                    NaN  [35, 18, 10749]
# 4  11862      0                96871.0             [35]
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#   production_companies  release_date  runtime spoken_languages  \
# 0                  [3]          1995     81.0              [1]
# 1   [559, 2550, 10201]          1995    104.0           [1, 2]
# 2        [6194, 19464]          1995    101.0              [1]
# 3                [306]          1995    127.0              [1]
# 4         [5842, 9195]          1995    106.0              [1]
#
#                          title  vote_average  vote_count  \
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0
#
#                                             keywords
# 0  [931, 4290, 5202, 6054, 9713, 9823, 165503, 17...
# 1       [10090, 10941, 15101, 33467, 158086, 158091]
# 2                      [1495, 12392, 179431, 208510]
# 3                  [818, 10131, 14768, 15160, 33455]
# 4  [1009, 1599, 2246, 4995, 5600, 10707, 13149, 3...

# %%
df_cleaned.to_csv("./new_movie_data/final_cleaned.csv",index = False)

# %%
df = pd.read_csv("./new_movie_data/final_cleaned.csv")

# %% [markdown]
# #### Forgot the credits file :(

# %%
df_c = pd.read_csv("./new_movie_data/credits.csv")
df_c_new = pd.merge(df,df_c,on='id')

# %%
[i.get('name') for i in eval(df_c_new.cast.iloc[0])]
# Out:
# ['Tom Hanks',
#  'Tim Allen',
#  'Don Rickles',
#  'Jim Varney',
#  'Wallace Shawn',
#  'John Ratzenberger',
#  'Annie Potts',
#  'John Morris',
#  'Erik von Detten',
#  'Laurie Metcalf',
#  'R. Lee Ermey',
#  'Sarah Freeman',
#  'Penn Jillette']

# %%
dict_ids_to_cast = dict()
l = []
for j in df_c_new.cast:
    l2 = []
    for i in sorted(eval(j), key=lambda d: d['order']):
        l2.append(i.get('id'))
        dict_ids_to_cast.update({i.get('id') : i.get('name')})
    l.append(l2)
df_c_new.cast = l

# %%
with open("./new_movie_data/dict/ids_to_cast.pkl","wb") as f:
    pickle.dump(dict_ids_to_cast,f)

# %%
with open("./new_movie_data/dict/ids_to_cast.pkl","rb") as f:
    d = pickle.load(f)
[d.get(i) for i in df_c_new.cast.iloc[0]]
# Out:
# ['Tom Hanks',
#  'Tim Allen',
#  'Don Rickles',
#  'Jim Varney',
#  'Wallace Shawn',
#  'John Ratzenberger',
#  'Annie Potts',
#  'John Morris',
#  'Erik von Detten',
#  'Laurie Metcalf',
#  'R. Lee Ermey',
#  'Sarah Freeman',
#  'Penn Jillette']

# %%
df_c_new.head()
# Out:
#       id  adult  belongs_to_collection           genres  \
# 0    862      0                10194.0  [16, 35, 10751]
# 1   8844      0                    NaN  [12, 14, 10751]
# 2  15602      0               119050.0      [10749, 35]
# 3  31357      0                    NaN  [35, 18, 10749]
# 4  11862      0                96871.0             [35]
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#   production_companies  release_date  runtime spoken_languages  \
# 0                  [3]          1995     81.0              [1]
# 1   [559, 2550, 10201]          1995    104.0           [1, 2]
# 2        [6194, 19464]          1995    101.0              [1]
# 3                [306]          1995    127.0              [1]
# 4         [5842, 9195]          1995    106.0              [1]
#
#                          title  vote_average  vote_count  \
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0
#
#                                             keywords  \
# 0  [931, 4290, 5202, 6054, 9713, 9823, 165503, 17...
# 1       [10090, 10941, 15101, 33467, 158086, 158091]
# 2                      [1495, 12392, 179431, 208510]
# 3                  [818, 10131, 14768, 15160, 33455]
# 4  [1009, 1599, 2246, 4995, 5600, 10707, 13149, 3...
#
#                                                 cast  \
# 0  [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...
# 1  [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2       [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3  [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# 4  [67773, 3092, 519, 70696, 59222, 18793, 14592,...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...

# %%
[i.get('name') for i in eval(df_c_new.crew.iloc[0])][:5]
# Out:
# ['John Lasseter',
#  'Joss Whedon',
#  'Andrew Stanton',
#  'Joel Cohen',
#  'Alec Sokolow']

# %%
dict_ids_to_crew = dict()
l = []
for i in df_c_new['crew']:
    l2 = []
    for j in eval(i):
        l2.append(j.get('id'))
        dict_ids_to_crew.update({j.get('id'): j.get('name')})
    l.append(l2)
df_c_new['crew'] = l

# %%
with open("./new_movie_data/dict/ids_to_crew.pkl","wb") as f:
    pickle.dump(dict_ids_to_crew,f)

# %%
with open("./new_movie_data/dict/ids_to_crew.pkl","rb") as f:
    d = pickle.load(f)
[d.get(i) for i in df_c_new.crew.iloc[0]][:5]
# Out:
# ['John Lasseter',
#  'Joss Whedon',
#  'Andrew Stanton',
#  'Joel Cohen',
#  'Alec Sokolow']

# %%
df_c_new.head()
# Out:
#       id  adult  belongs_to_collection           genres  \
# 0    862      0                10194.0  [16, 35, 10751]
# 1   8844      0                    NaN  [12, 14, 10751]
# 2  15602      0               119050.0      [10749, 35]
# 3  31357      0                    NaN  [35, 18, 10749]
# 4  11862      0                96871.0             [35]
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#   production_companies  release_date  runtime spoken_languages  \
# 0                  [3]          1995     81.0              [1]
# 1   [559, 2550, 10201]          1995    104.0           [1, 2]
# 2        [6194, 19464]          1995    101.0              [1]
# 3                [306]          1995    127.0              [1]
# 4         [5842, 9195]          1995    106.0              [1]
#
#                          title  vote_average  vote_count  \
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0
#
#                                             keywords  \
# 0  [931, 4290, 5202, 6054, 9713, 9823, 165503, 17...
# 1       [10090, 10941, 15101, 33467, 158086, 158091]
# 2                      [1495, 12392, 179431, 208510]
# 3                  [818, 10131, 14768, 15160, 33455]
# 4  [1009, 1599, 2246, 4995, 5600, 10707, 13149, 3...
#
#                                                 cast  \
# 0  [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...
# 1  [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2       [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3  [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# 4  [67773, 3092, 519, 70696, 59222, 18793, 14592,...
#
#                                                 crew
# 0  [7879, 12891, 7, 12892, 12893, 12894, 12895, 1...
# 1  [511, 876, 1729, 4945, 4951, 4952, 8023, 9967,...
# 2                     [26502, 16837, 16837, 1551320]
# 3  [2178, 5144, 5144, 21968, 70592, 111118, 11111...
# 4      [37, 5506, 17698, 17698, 26160, 56106, 68755]

# %%
df_c_new.to_csv("./new_movie_data/final_cleaned_2.csv",index = False)

# %%
df = pd.read_csv("./new_movie_data/final_cleaned_2.csv")
df
# Out:
#            id  adult  belongs_to_collection           genres  \
# 0         862      0                10194.0  [16, 35, 10751]
# 1        8844      0                    NaN  [12, 14, 10751]
# 2       15602      0               119050.0      [10749, 35]
# 3       31357      0                    NaN  [35, 18, 10749]
# 4       11862      0                96871.0             [35]
# ...       ...    ...                    ...              ...
# 46159  439050      0                    NaN      [18, 10751]
# 46160  111109      0                    NaN             [18]
# 46161   67758      0                    NaN     [28, 18, 53]
# 46162  227506      0                    NaN               []
# 46163  461257      0                    NaN               []
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 46159        Rising and falling between a man and woman.    0.072051
# 46160  An artist struggles to finish his work while a...    0.178241
# 46161  When one of her hits goes wrong, a professiona...    0.903007
# 46162  In a small town live two brothers, one a minis...    0.003503
# 46163  50 years after decriminalisation of homosexual...    0.163015
#
#       production_companies  release_date  runtime spoken_languages  \
# 0                      [3]          1995     81.0              [1]
# 1       [559, 2550, 10201]          1995    104.0           [1, 2]
# 2            [6194, 19464]          1995    101.0              [1]
# 3                    [306]          1995    127.0              [1]
# 4             [5842, 9195]          1995    106.0              [1]
# ...                    ...           ...      ...              ...
# 46159                   []             0     90.0             [14]
# 46160              [19653]          2011    360.0             [32]
# 46161               [6165]          2003     90.0              [1]
# 46162              [88753]          1917     87.0               []
# 46163                   []          2017     75.0              [1]
#
#                              title  vote_average  vote_count  \
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 46159                       Subdue           4.0         1.0
# 46160          Century of Birthing           9.0         3.0
# 46161                     Betrayal           3.8         6.0
# 46162             Satan Triumphant           0.0         0.0
# 46163                     Queerama           0.0         0.0
#
#                                                 keywords  \
# 0      [931, 4290, 5202, 6054, 9713, 9823, 165503, 17...
# 1           [10090, 10941, 15101, 33467, 158086, 158091]
# 2                          [1495, 12392, 179431, 208510]
# 3                      [818, 10131, 14768, 15160, 33455]
# 4      [1009, 1599, 2246, 4995, 5600, 10707, 13149, 3...
# ...                                                  ...
# 46159                                            [10703]
# 46160                              [2679, 14531, 215397]
# 46161                                                 []
# 46162                                                 []
# 46163                                                 []
#
#                                                     cast  \
# 0      [31, 12898, 7167, 12899, 12900, 7907, 8873, 11...
# 1      [2157, 8537, 205, 145151, 5149, 10739, 58563, ...
# 2           [6837, 3151, 13567, 16757, 589, 16523, 7166]
# 3      [8851, 9780, 18284, 51359, 66804, 352, 87118, ...
# 4      [67773, 3092, 519, 70696, 59222, 18793, 14592,...
# ...                                                  ...
# 46159                         [240240, 1749839, 1619957]
# 46160  [1043186, 111636, 1204271, 278923, 1042953, 57...
# 46161  [23764, 2059, 46277, 1736, 58646, 54649, 55270...
# 46162         [544742, 1090923, 1136422, 1261758, 29199]
# 46163                                                 []
#
#                                                     crew
# 0      [7879, 12891, 7, 12892, 12893, 12894, 12895, 1...
# 1      [511, 876, 1729, 4945, 4951, 4952, 8023, 9967,...
# 2                         [26502, 16837, 16837, 1551320]
# 3      [2178, 5144, 5144, 21968, 70592, 111118, 11111...
# 4          [37, 5506, 17698, 17698, 26160, 56106, 68755]
# ...                                                  ...
# 46159  [1182809, 1182809, 1543705, 1749842, 1749847, ...
# 46160  [1051381, 1051381, 1728582, 1051381, 1051381, ...
# 46161              [67753, 19713, 549355, 549356, 58818]
# 46162                                 [1085341, 1195656]
# 46163                                          [1344495]
#
# [46164 rows x 16 columns]
